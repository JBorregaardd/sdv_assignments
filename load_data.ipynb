# %%
import pandas as pd
import matplotlib.pyplot as plt


#datafile with crime data form 
data = pd.read_csv('df_assignment.csv')

data.to_csv("df_assignment.csv.gz", index=False)


focus_crime = [
    "larceny theft",
    "motor vehicle theft",
    "robbery",
    "assault",
    "drug offense",
    "weapons offense",
    "vandalism",
    "rape"
]
