# %%
import pandas as pd
import matplotlib.pyplot as plt


#datafile with crime data form 
df = pd.read_csv("df_assignment.csv.gz", )


focus_crime = [
    "larceny theft",
    "motor vehicle theft",
    "robbery",
    "assault",
    "drug offense",
    "weapons offense",
    "vandalism",
    "rape"
]

df.head()
# Out:
#               datetime  year             category police_district  \
# 0  2016-03-03 19:30:00  2016  motor vehicle theft         taraval
# 1  2013-02-10 18:09:00  2013              assault         mission
# 2  2006-09-25 22:15:00  2006              assault        northern
# 3  2011-06-19 13:06:00  2011       other offenses         taraval
# 4  2008-05-23 12:10:00  2008              assault        northern
#
#          description   longitude   latitude  \
# 0  stolen automobile -122.463545  37.707968
# 1            battery -122.425237  37.754222
# 2            battery -122.425839  37.778486
# 3        trespassing -122.466758  37.729185
# 4            battery -122.423582  37.775904
#
#                               location source
# 0  point (-122.463545017 37.707968365)    old
# 1  point (-122.425236707 37.754222191)    old
# 2   point (-122.42583948 37.778486375)    old
# 3   point (-122.466758005 37.72918458)    old
# 4  point (-122.423581857 37.775904267)    old
